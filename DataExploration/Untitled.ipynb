# %%
import numpy as np
import pandas as pd

# %%
# Read CSV
pd.set_option('display.max_columns', None)
raw_data = pd.read_csv("../Resources/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")
raw_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0       2012     2012           WY               Wyoming
# 1       2012     2012           DC  District of Columbia
# 2       2011     2011           AL               Alabama
# 3       2013     2013           US              National
# 4       2011     2011           US              National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System        Physical Activity
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0       Obesity / Weight Status
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3  Physical Activity - Behavior
# 4  Physical Activity - Behavior
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults aged 18 years and older who ...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults who engage in no leisure-tim...              NaN
# 4  Percent of adults who engage in no leisure-tim...              NaN
#
#   Data_Value_Type  Data_Value  Data_Value_Alt Data_Value_Footnote_Symbol  \
# 0           Value        48.5            48.5                        NaN
# 1           Value        31.6            31.6                        NaN
# 2           Value        35.2            35.2                        NaN
# 3           Value        27.9            27.9                        NaN
# 4           Value        16.9            16.9                        NaN
#
#   Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit   \
# 0                 NaN                  32.3                    64.9
# 1                 NaN                  24.0                    40.4
# 2                 NaN                  30.7                    40.0
# 3                 NaN                  27.6                    28.3
# 4                 NaN                  16.0                    17.8
#
#   Sample_Size Total Age(years)              Education  Gender Income  \
# 0          69   NaN        NaN                    NaN     NaN    NaN
# 1         243   NaN        NaN  Less than high school     NaN    NaN
# 2         598   NaN    25 - 34                    NaN     NaN    NaN
# 3     266,452   NaN        NaN                    NaN  Female    NaN
# 4      20,923   NaN    18 - 24                    NaN     NaN    NaN
#
#                   Race/Ethnicity                     GeoLocation ClassID  \
# 0  American Indian/Alaska Native  (43.235541343, -108.109830353)     OWS
# 1                            NaN   (38.890371385, -77.031961127)     OWS
# 2                            NaN   (32.840571122, -86.631860762)     OWS
# 3                            NaN                             NaN      PA
# 4                            NaN                             NaN      PA
#
#   TopicID QuestionID DataValueTypeID  LocationID StratificationCategory1  \
# 0    OWS1       Q037           VALUE          56          Race/Ethnicity
# 1    OWS1       Q036           VALUE          11               Education
# 2    OWS1       Q036           VALUE           1             Age (years)
# 3     PA1       Q047           VALUE          59                  Gender
# 4     PA1       Q047           VALUE          59             Age (years)
#
#                  Stratification1 StratificationCategoryId1 StratificationID1
# 0  American Indian/Alaska Native                      RACE           RACENAA
# 1          Less than high school                       EDU             EDUHS
# 2                        25 - 34                     AGEYR         AGEYR2534
# 3                         Female                       GEN            FEMALE
# 4                        18 - 24                     AGEYR         AGEYR1824

# %%
trim_data = raw_data[["YearStart", "LocationAbbr", "LocationDesc", "Question", "Data_Value", "Age(years)", "Education",
                     "Race/Ethnicity", "Gender", "Income", "StratificationCategory1"]]
trim_data.head()
# Out:
#    YearStart LocationAbbr          LocationDesc  \
# 0       2012           WY               Wyoming
# 1       2012           DC  District of Columbia
# 2       2011           AL               Alabama
# 3       2013           US              National
# 4       2011           US              National
#
#                                             Question  Data_Value Age(years)  \
# 0  Percent of adults aged 18 years and older who ...        48.5        NaN
# 1  Percent of adults aged 18 years and older who ...        31.6        NaN
# 2  Percent of adults aged 18 years and older who ...        35.2    25 - 34
# 3  Percent of adults who engage in no leisure-tim...        27.9        NaN
# 4  Percent of adults who engage in no leisure-tim...        16.9    18 - 24
#
#                Education                 Race/Ethnicity  Gender Income  \
# 0                    NaN  American Indian/Alaska Native     NaN    NaN
# 1  Less than high school                            NaN     NaN    NaN
# 2                    NaN                            NaN     NaN    NaN
# 3                    NaN                            NaN  Female    NaN
# 4                    NaN                            NaN     NaN    NaN
#
#   StratificationCategory1
# 0          Race/Ethnicity
# 1               Education
# 2             Age (years)
# 3                  Gender
# 4             Age (years)

# %%
trim_data = trim_data.loc[(trim_data["Question"] == "Percent of adults aged 18 years and older who have obesity")]

# %%
age_data = trim_data[["YearStart", "LocationAbbr", "LocationDesc", "Data_Value", "Age(years)"]]
age_data.dropna()
# Out:
#        YearStart LocationAbbr LocationDesc  Data_Value   Age(years)
# 2           2011           AL      Alabama        35.2      25 - 34
# 30          2015           NY     New York        29.7      35 - 44
# 87          2013           WA   Washington        33.3      45 - 54
# 91          2011           TN    Tennessee        32.5      55 - 64
# 103         2014           NM   New Mexico        33.2      25 - 34
# ...          ...          ...          ...         ...          ...
# 62950       2014           TX        Texas        30.7  65 or older
# 62955       2013           TN    Tennessee        40.3      35 - 44
# 62996       2014           AR     Arkansas        29.2  65 or older
# 63008       2014           TN    Tennessee        39.3      45 - 54
# 63014       2012           AZ      Arizona        22.6  65 or older
#
# [2568 rows x 5 columns]
